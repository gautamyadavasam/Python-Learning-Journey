# %% [markdown]
# Dictionary

# %%
#Basic Syntax of Dictionary
My_dict ={'Key1':'Value1' , 'Key2':'value2'}

# %%
my

# %%
def first_unique_character(user_input):
    from collections import Counter
    freq = Counter(user_input)
    
    for i, ch in enumerate(user_input):
        if freq[ch] == 1:
            return i
    
    return -1
