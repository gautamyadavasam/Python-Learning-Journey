# %%
import pandas as pd 
import numpy as np

# %%
data []
for
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 data = input(list= [])
#       2 print(list)
#
# TypeError: Kernel.raw_input() got an unexpected keyword argument 'list'

# %%
row1 =list[:3]
one =row1.copy()
print(one)
type(one)
# Out:
# [1, 2, 3]
# list

# %%
row2 = list[3:6]
two = row2.copy()
print(two)
# Out:
# [4, 5, 6]

# %%
row3 = list[6:9]
three = row3.copy()
print(three)
# Out:
# [7, 8, 9]

# %%
dict={'col1': one,'col2':two,'col3':three}
print(dict)
# Out:
# {'col1': [1, 2, 3], 'col2': [4, 5, 6], 'col3': [7, 8, 9]}
