# %%
import pandas as pd

# %%
history_marks = [20, 30, 40, 56, 78, 67, 67]
english_marks = [38,32,65,76,98,56,24]

# %%
students_marks = pd.DataFrame({"History":history_marks, "english":english_marks})

# %%
print(students_marks)
# Out:
#    History  english
# 0       20       38
# 1       30       32
# 2       40       65
# 3       56       76
# 4       78       98
# 5       67       56
# 6       67       24
